# %% [markdown]
# # Clasificación con redes neuronales
#
# En este notebook simple usaremos una FCNN (completamente conectada) para resolver el problema de clasificación de ID de partículas, visto previamente para SVMs.
#
# Basado en Machine learning for physics and Astronomy, Viviana Acquaviva (2023)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.utils import shuffle

# %%
import matplotlib
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 150)

font = {'size'   : 16}
matplotlib.rc('font', **font)
matplotlib.rc('xtick', labelsize=14)
matplotlib.rc('ytick', labelsize=14)
matplotlib.rcParams['figure.dpi'] = 300

# %% [markdown]
# ### Librerías para Deep Learning
#
# [Tensorflow](https://www.tensorflow.org/?hl=es-419) es una biblioteca de uso muy común para el desarrollo de modelos de aprendizaje profundo. Es una plataforma de código abierto desarrollada por Google. Admite programación en varios lenguajes, como C++, Java, Python, y muchos otros.
#
# [Keras](https://keras.io/) es una API de alto nivel (Application Programming Interface) construida sobre TensorFlow (o Theano, otra biblioteca de aprendizaje profundo). Es específica para Python, y podemos pensar en ella como el equivalente de la biblioteca sklearn, pero para redes neuronales. Es menos general y menos personalizable, pero muy fácil de usar y comparativamente más sencilla que TensorFlow.
#
# [PyTorch](https://pytorch.org/) es otra biblioteca muy popular para el desarrollo de modelos de aprendizaje profundo, desarrollada por Meta (Facebook). A diferencia de Keras, no es una API de alto nivel sobre otra biblioteca, sino un framework completo en sí mismo. Es especialmente popular en investigación por su flexibilidad para construir arquitecturas no estándar, aunque eso viene con una curva de aprendizaje más pronunciada y bastante más código para tareas simples.
#
# En este curso usaremos Keras con TensorFlow como back-end, porque para los problemas que veremos su simplicidad tiene más peso que la flexibilidad extra de PyTorch.

# %% [markdown]
# **Comparación**
#
# | | TensorFlow | Keras | PyTorch |
# |---|---|---|---|
# | **Qué es** | Framework completo | API de alto nivel (sobre TensorFlow) | Framework completo |
# | **Desarrollado por** | Google | Ahora integrado a TensorFlow | Meta (Facebook) |
# | **Curva de aprendizaje** | Media-alta | Baja | Media-alta |
# | **Líneas de código para un modelo simple** | Muchas | Pocas | Muchas |
# | **Flexibilidad para arquitecturas no estándar** | Alta | Media | Muy alta |
# | **Dónde se usa más** | Producción, industria | Prototipado rápido, docencia | Investigación, papers recientes |

# %%
import sys
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
#!pip install tensorflow

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.20.0'

# %% [markdown]
# Importamos `keras` y usaremos `Sequential`, que admite una entrada y una salida

# %%
import keras

from keras.models import Sequential # El modelo se construye agregando una capa después de otra

from keras.layers import Dense #totalmente conectadas: cada output se conecta con cada input

from keras.layers import Dropout #para regularización

# %% [markdown]
# Comenzamos con el problema de 4top vs ttbar, y utilizamos la configuración en la que añadimos las características "número de leptones", "número de jets", etc. Como referencia, el SVM óptimo alcanzó un 94-95% de precisión. Cabe destacar que esos números no se obtuvieron utilizando validación cruzada anidada, por lo que podrían ser ligeramente optimistas.

# %%
X = pd.read_csv('Features_lim_2.csv')

# %%
y = np.genfromtxt('Labels_lim_2.txt')

# %%
X.values.shape
# Out:
# (5000, 24)

# %%
X.head()
# Out:
#    ID      MET    METphi        P1        P2        P3        P4        P5  \
# 0   0  62803.5 -1.810010  137571.0  128444.0 -0.345744 -0.307112  174209.0
# 1   1  57594.2 -0.509253  161529.0   80458.3 -1.318010  1.402050  291490.0
# 2   2  82313.3  1.686840  167130.0  113078.0  0.937258 -2.068680  102423.0
# 3   3  30610.8  2.617120  112267.0   61383.9 -1.211050 -1.457800   40647.8
# 4   4  45153.1 -2.241350  178174.0  100164.0  1.166880 -0.018721   92351.3
#
#          P6        P7        P8        P9      P10       P11       P12  \
# 0  127932.0  0.826569  2.332000   86788.9  84554.9 -0.180795  2.187970
# 1   68462.9 -2.126740 -2.582310   44270.1  35139.6 -0.706120 -0.371392
# 2   54922.3  1.226850  0.646589   60768.9  36244.3  1.102890 -1.434480
# 3   39472.0 -0.024646 -2.222800  201589.0  32978.6 -2.496040  1.137810
# 4   69762.1  0.774114  2.568740   61625.2  50086.7  0.652572 -3.012800
#
#         P13      P14      P15       P16  Total_products  Total_b  Total_j  \
# 0  140289.0  76955.8 -1.19933 -1.302800               5        1        3
# 1   72883.9  26902.2 -1.65386 -3.129630               4        0        2
# 2   77714.0  27801.5  1.68461  1.389690               5        1        4
# 3   90096.7  26964.5  1.87132  0.817631               5        1        4
# 4  104193.0  31151.0  1.87641  0.865381               5        0        5
#
#    Total_g  Total_leptons
# 0        0              1
# 1        0              2
# 2        0              0
# 3        0              0
# 4        0              0

# %%
y
# Out:
# array([0., 0., 0., ..., 0., 1., 0.])

# %% [markdown]
# Aquí no hay un proceso de validación cruzada "integrado", por lo que tendríamos que implementarlo nosotros mismos. Por ahora, podemos construir tres conjuntos: entrenamiento, validación (para la optimización de parámetros) y prueba (para la evaluación final). Idealmente, deberíamos estructurarlo como una validación cruzada.
#
# En la práctica, rara vez se hace CV k-fold completa con redes neuronales. Cada fold implica reentrenar la red desde cero, así que el costo computacional escala rápido: con 5 folds ya estamos pagando 5 veces el costo de entrenamiento, y eso antes de siquiera empezar a buscar hiperparámetros. Además, la razón principal para usar CV es obtener una estimación confiable del desempeño cuando el dataset es chico; con datasets grandes (el escenario típico donde las NN funcionan mejor), un solo split bien hecho ya da una estimación razonablemente estable.
#
# Por eso optamos por un split fijo train/validación/prueba, y usamos el set de validación para *early stopping* y ajuste de hiperparámetros. Esto evita el costo de CV sin sacrificar demasiado rigor.

# %% [markdown]
# #### Sets de entrenamiento y prueba
#
# Este dataset tiene un desbalance importante entre las dos clases. Para que esa proporción se mantenga en cada split, usamos `stratify` al dividir los datos.

# %%
clase, total = np.unique(y, return_counts=True)
print(dict(zip(clase, total)))
# Out:
# {np.float64(0.0): np.int64(4189), np.float64(1.0): np.int64(811)}

# %%
razon = total[1] / total[0]
print(f"Razón: {razon:.2f}")
# Out:
# Razón: 0.19

# %%
# Primero separamos test (20%), estratificado por clase
X_temp, X_test, y_temp, y_test = train_test_split(
    X.values, y, test_size=0.2, stratify=y, random_state=10
)

# Del resto, separamos train/val (80/20 de lo que queda)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.2, stratify=y_temp, random_state=10
)

print(X_train.shape, X_val.shape, X_test.shape)
print("Balance train:", y_train.mean(), "| val:", y_val.mean(), "| test:", y_test.mean())
# Out:
# (3200, 24) (800, 24) (1000, 24)
# Balance train: 0.1621875 | val: 0.1625 | test: 0.162

# %% [markdown]
# ### Construyendo la red

# %% [markdown]
# Pensemos en la arquitectura del modelo.
#
# Nuestra capa de entrada tiene **24 neuronas** (24 características)
#
# Nuestra capa de salida tiene **una neurona** (la salida es la probabilidad de que el objeto pertenezca a la clase positiva). También podríamos configurarla con dos neuronas (y usar softmax como la no linealidad final), pero esto es redundante en un problema de clasificación binaria. La neurona de salida será una función **sigmoide**
#
# Añadiremos **dos capas ocultas**. En este caso, ambas tienen tamaño = 20 (debemos optimizar este hiperparámetro!). También podemos reservar la posibilidad de añadir una capa de dropout después de cada una.
#
# Otras decisiones que debemos tomar son: qué no linealidades usar (por ahora: ReLU para las capas ocultas, sigmoide para la final), qué optimizador usar (Adam), qué tasa de aprendizaje inicial adoptar (aquí 0.001, aunque nuevamente esto debería decidirse mediante CV), el número de épocas (por ejemplo, 100; podemos graficar cantidades de interés para verificar que esto sea suficiente), el tamaño de lote (batch size) para el paso de descenso por gradiente (aquí 200, pero podemos explorarlo!) y la función de pérdida. Esta última es la entropía cruzada binaria ([binary cross entropy](https://towardsdatascience.com/understanding-binary-cross-entropy-log-loss-a-visual-explanation-a3ac6025181a)), que es la elección estándar para problemas de clasificación donde la salida es una probabilidad. Premia la "confianza" en una predicción correcta (alta probabilidad).

# %% [markdown]
# El siguiente comando nos ayuda a explorar todas las posibles opciones

# %%
dir(keras.optimizers)
# Out:
# ['Adadelta',
#  'Adafactor',
#  'Adagrad',
#  'Adam',
#  'AdamW',
#  'Adamax',
#  'Ftrl',
#  'Lamb',
#  'Lion',
#  'LossScaleOptimizer',
#  'Muon',
#  'Nadam',
#  'Optimizer',
#  'RMSprop',
#  'SGD',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'deserialize',
#  'get',
#  'legacy',
#  'schedules',
#  'serialize']

# %%
dir(keras.losses)
# Out:
# ['BinaryCrossentropy',
#  'BinaryFocalCrossentropy',
#  'CTC',
#  'CategoricalCrossentropy',
#  'CategoricalFocalCrossentropy',
#  'CategoricalGeneralizedCrossEntropy',
#  'CategoricalHinge',
#  'Circle',
#  'CosineSimilarity',
#  'Dice',
#  'Hinge',
#  'Huber',
#  'KLDivergence',
#  'LogCosh',
#  'Loss',
#  'MeanAbsoluteError',
#  'MeanAbsolutePercentageError',
#  'MeanSquaredError',
#  'MeanSquaredLogarithmicError',
#  'Poisson',
#  'SparseCategoricalCrossentropy',
#  'SquaredHinge',
#  'Tversky',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'binary_crossentropy',
#  'binary_focal_crossentropy',
#  'categorical_crossentropy',
#  'categorical_focal_crossentropy',
#  'categorical_generalized_cross_entropy',
#  'categorical_hinge',
#  'circle',
#  'cosine_similarity',
#  'ctc',
#  'deserialize',
#  'dice',
#  'get',
#  'hinge',
#  'huber',
#  'kl_divergence',
#  'log_cosh',
#  'mean_absolute_error',
#  'mean_absolute_percentage_error',
#  'mean_squared_error',
#  'mean_squared_logarithmic_error',
#  'poisson',
#  'serialize',
#  'sparse_categorical_crossentropy',
#  'squared_hinge',
#  'tversky']

# %% [markdown]
# La opción estándar para un caso como el nuestro, donde las etiquetas son 0/1, pero podemos predecir una probabilidad, es binary cross-entropy or log loss:
#
# L = - $\frac{1}{N} \sum_{i=1}^N y_i \cdot log(p(y_i)) + (1-y_i) \cdot log (1 - p(y_i))$

# %% [markdown]
# $p$ es la probabilidad de que un objeto pertenezca a la clase positiva. Penaliza los ejemplos positivos que están asociados con una probabilidad predicha baja, y los ejemplos negativos que están asociados con una probabilidad predicha alta.

# %% [markdown]
# Acá una lista de funciones de activación

# %%
dir(keras.activations)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'celu',
#  'deserialize',
#  'elu',
#  'exponential',
#  'gelu',
#  'get',
#  'glu',
#  'hard_shrink',
#  'hard_sigmoid',
#  'hard_silu',
#  'hard_swish',
#  'hard_tanh',
#  'leaky_relu',
#  'linear',
#  'log_sigmoid',
#  'log_softmax',
#  'mish',
#  'relu',
#  'relu6',
#  'selu',
#  'serialize',
#  'sigmoid',
#  'silu',
#  'soft_shrink',
#  'softmax',
#  'softplus',
#  'softsign',
#  'sparse_plus',
#  'sparse_sigmoid',
#  'sparsemax',
#  'squareplus',
#  'swish',
#  'tanh',
#  'tanh_shrink',
#  'threshold']

# %% [markdown]
# ### Así es como construímos la red completamente conectada en Keras

# %%
model = Sequential()

# Primera capa oculta, especificamos el tamaño del input (número de características originales)

model.add(Dense(20, activation='relu', input_shape=(24,)))

# Agrega una  segunda capa oculta y especificamos el tamaño

model.add(Dense(20, activation='relu'))

# Agrega capa de salida

model.add(Dense(1, activation='sigmoid'))

model.summary() # resumen de la arquitectura
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_19 (Dense)                │ (None, 20)             │           500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 941 (3.68 KB)
#  Trainable params: 941 (3.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 1. Agregando una tercera capa oculta (20 neuronas)

# %%
model_third_layer = Sequential()
model_third_layer.add(Dense(20, activation='relu', input_shape=(24,)))
model_third_layer.add(Dense(20, activation='relu'))
model_third_layer.add(Dense(20, activation='relu')) # Tercera capa oculta
model_third_layer.add(Dense(1, activation='sigmoid'))

print("Modelo con 3 capas ocultas (20 neuronas cada una):")
model_third_layer.summary()
# Out:
# Modelo con 3 capas ocultas (20 neuronas cada una):
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_22 (Dense)                │ (None, 20)             │           500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,361 (5.32 KB)
#  Trainable params: 1,361 (5.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 2. Cambiando el tamaño de las capas ocultas a 5 neuronas

# %%
model_small_layers = Sequential()
model_small_layers.add(Dense(5, activation='relu', input_shape=(24,)))
model_small_layers.add(Dense(5, activation='relu'))
model_small_layers.add(Dense(1, activation='sigmoid'))

print("Modelo con 2 capas ocultas (5 neuronas cada una):")
model_small_layers.summary()
# Out:
# Modelo con 2 capas ocultas (5 neuronas cada una):
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_26 (Dense)                │ (None, 5)              │           125 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 5)              │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 161 (644.00 B)
#  Trainable params: 161 (644.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 2. Cambiando el tamaño de las capas ocultas a 100 neuronas

# %%
model_large_layers = Sequential()
model_large_layers.add(Dense(100, activation='relu', input_shape=(24,)))
model_large_layers.add(Dense(100, activation='relu'))
model_large_layers.add(Dense(1, activation='sigmoid'))

print("Modelo con 2 capas ocultas (100 neuronas cada una):")
model_large_layers.summary()
# Out:
# Modelo con 2 capas ocultas (100 neuronas cada una):
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_29 (Dense)                │ (None, 100)            │         2,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,701 (49.61 KB)
#  Trainable params: 12,701 (49.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 3. Cambiando la función de activación a `tanh`

# %%
model_tanh_activation = Sequential()
model_tanh_activation.add(Dense(20, activation='tanh', input_shape=(24,)))
model_tanh_activation.add(Dense(20, activation='tanh'))
model_tanh_activation.add(Dense(1, activation='sigmoid'))

print("Modelo con 2 capas ocultas (20 neuronas cada una, activación tanh):")
model_tanh_activation.summary()
# Out:
# Modelo con 2 capas ocultas (20 neuronas cada una, activación tanh):
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_32 (Dense)                │ (None, 20)             │           500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 941 (3.68 KB)
#  Trainable params: 941 (3.68 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy'])

# %% [markdown]
# Con el keyword `métrica` podemos cambiar a la métrica que queremos ver. El valor absoluto de la pérdida no se traduce directamente en algo intuitivo (a diferencia de accuracy, que sí es un % de aciertos), aunque sigue siendo muy útil para comparar train vs. validación y detectar overfitting.

# %% [markdown]
# ### Ahora pruebe usted
#
# Usando el mismo código de arriba como plantilla, modifíquelo para responder:
#
# **¿Qué pasa si agrega una tercera capa oculta?** Agréguela (por ejemplo, de tamaño 20 también) y comenten: ¿por qué una arquitectura más profunda podría ayudar o no ayudar en este problema?
#
# Como era de esperar, añadir una tercera capa oculta aumenta el número total de parámetros (Total params: 1,361) en comparación con el modelo base de dos capas. Una red más profunda (más capas) aumenta la capacidad del modelo para aprender representaciones más complejas y jerárquicas de los datos
#
# **¿Qué pasa si cambia el tamaño de las capas ocultas** (por ejemplo, de 20 a 5, o de 20 a 100)? Antes de correrlo: ¿espera que la red sea más lenta o más rápida de entrenar? ¿Más o menos propensa a sobreajustar?
#
# Reducir el número de neuronas a 5 por capa disminuye drásticamente el número de parámetros. Una red con menos parámetros es generalmente más rápida de entrenar y menos propensa al sobreajuste, pero podría tener menos capacidad para aprender patrones complejos. Ahora, aumentar el número de neuronas a 100 por capa incrementa significativamente el número de parámetros. Una red con más parámetros tiene mayor capacidad para aprender, pero es más lenta de entrenar y más propensa al sobreajuste si no se regula adecuadamente.
#
# **¿Qué pasa si usa otra función de activación** en las capas ocultas (por ejemplo `tanh` en vez de `relu`)? Revise la lista de activaciones disponibles que exploramos arriba con `dir(keras.activations)`.
#
# En este caso, el número de parámetros se mantiene igual que en el modelo base (2 capas de 20 neuronas), ya que la función de activación no afecta directamente el conteo de parámetros entrenables de las capas densas.
#
# No hace falta entrenar todavía, solo construyan el modelo con `model.summary()` al final y observe cómo cambia el número de parámetros totales según sus decisiones.

# %% [markdown]
# ### Listos para ajustar!
#
# Nota también los hiperparámetros adicionales "epochs" (el número de pasadas completas de ida y vuelta sobre el conjunto de datos) y "batch size" (cuántos datos se utilizan en cada paso para actualizar los pesos).

# %% [markdown]
# ### Antes de correr esto
#
# ¿Qué accuracy espera que logre esta red? Como referencia, el SVM óptimo llegó a 94-95%. Escriba su predicción antes de correr la celda de abajo.
#
# > Mi predicción de accuracy: 85-90%

# %%
mynet = model.fit(X_train, y_train, validation_data= (X_val, y_val), epochs = 100,  batch_size=200)
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0


# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %% [markdown]
# Escalamos sólo los datos del set entrenamiento (para evitar leakage)

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
Xst_train = scaler.transform(X_train)
Xst_val = scaler.transform(X_val)
Xst_test = scaler.transform(X_test)

# %% [markdown]
# ### Reentrenamos la red

# %%
model_st = Sequential()
model_st.add(Dense(20, activation='relu', input_shape=(24,)))
model_st.add(Dense(20, activation='relu'))
model_st.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_st.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

mynet_st = model_st.fit(
    Xst_train, y_train, validation_data=(Xst_val, y_val),
    epochs=100, batch_size=200, verbose=0) #verbose=0 para no mostrar el resultado en cada epoca
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
plt.figure(figsize=(14,5))

plt.subplot(121)

plt.plot(mynet_st.history['loss'], label = 'train')
plt.plot(mynet_st.history['val_loss'],'-.m', label = 'validation')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(loc='upper right', fontsize = 12)

plt.subplot(122)

plt.plot(mynet_st.history['accuracy'], label = 'train')
plt.plot(mynet_st.history['val_accuracy'], '-.m', label = 'validation')
plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(fontsize = 12)
plt.subplots_adjust(wspace=0.5)
#plt.show()

#plt.savefig('ScaledNN.png', dpi= 300)

# %% [markdown]
# #### Ahora se ve mucho mejor el comportamiento de la red, y además se alcanza un accuracy similar a lo que obtuvimos con SVMs
#
# Esto es común para datos tabulares, que tienen relaciones más simples y en general no contienen demasiados datos. Las NN funcionan mejor para datos más complejos, como audio, imágenes, texto

# %% [markdown]
# ### Diagnóstico
#
# Mire las curvas de loss y accuracy  (train vs. validación, con datos escalados).
#
# 1. ¿Hay separación entre las curvas de train y validación? ¿Es una separación que se mantiene estable, o una que crece con las épocas?
#
# Sí, hay una separación creciente entre las curvas de entrenamiento y validación, tanto en la pérdida como en la precisión.
#
# 2. ¿esto califica como overfitting severo, overfitting leve, o no hay overfitting? Justifique mirando específicamente sus números, no una regla general.
#
#  Esto indica un sobreajuste leve, ya que el modelo se está ajustando demasiado a los datos de entrenamiento.
#
# 3. Según su diagnóstico, ¿tiene sentido aplicar regularización acá, o el modelo ya está bien como está?
#
# Sí, tiene sentido aplicar regularización para mejorar la capacidad de generalización del modelo.

# %% [markdown]
# ### Ahora pruebe usted
#
# La red original cuenta con dos capas ocultas de 20 neuronas cada una, ReLU, y salida sigmoide, entrenada con datos escalados. Usando ese mismo código como plantilla, construya y entrene tres variantes, una a la vez:
#
# 1. **Agregue una tercera capa oculta** (de 20 neuronas también). ¿Mejora, empeora, o no cambia mucho el accuracy de validación? ¿Por qué creen que pasa eso en este dataset específico?
#
# 2. **Cambie el tamaño de las capas ocultas** a algo mucho más chico (5 neuronas) y después a algo mucho más grande (100 neuronas). ¿Cuál entrena más lento? ¿Cuál muestra más señales de sobreajuste en las curvas de loss?
#
# 3. **Cambie la activación** de las capas ocultas de `relu` a `tanh`. Usen `dir(keras.activations)` si quieren ver más opciones. ¿Cambia la velocidad de convergencia?
#
# Rellene la tabla de comparación
#
# | Variante | val_accuracy | val_loss | Comentario |
# |---|---|---|---|
# | Baseline (2 capas x 20, relu) | 0.9388 | 0.1696 | Modelo original con datos escalados |
# | 3 capas ocultas | 0.9375 | 0.2363 | Ligeramente peor accuracy, mayor loss. Incrementa sobreajuste. |
# | Capas de 5 neuronas | 0.9463 | 0.1417 | Mejor accuracy, menor loss. Menos sobreajuste, más robusto. |
# | Capas de 100 neuronas | 0.9250 | 0.4310 | Peor accuracy, mucho mayor loss. Sobreajuste severo. |
# | Activación tanh | 0.9300 | 0.1816 | Ligeramente peor accuracy, similar loss. Convergencia comparable. |

# %% [markdown]
# ### 1. Variante: Agregando una tercera capa oculta (20 neuronas)

# %%
model_3_layers = Sequential()
model_3_layers.add(Dense(20, activation='relu', input_shape=(24,)))
model_3_layers.add(Dense(20, activation='relu'))
model_3_layers.add(Dense(20, activation='relu')) # Tercera capa oculta
model_3_layers.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_3_layers.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

print("Entrenando modelo con 3 capas ocultas...")
mynet_3_layers = model_3_layers.fit(
    Xst_train, y_train, validation_data=(Xst_val, y_val),
    epochs=100, batch_size=200, verbose=0)

plt.figure(figsize=(14,5))
plt.subplot(121)
plt.plot(mynet_3_layers.history['loss'], label = 'train')
plt.plot(mynet_3_layers.history['val_loss'],'-.m', label = 'validation')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(loc='upper right', fontsize = 12)
plt.title('Pérdida del modelo con 3 capas ocultas')

plt.subplot(122)
plt.plot(mynet_3_layers.history['accuracy'], label = 'train')
plt.plot(mynet_3_layers.history['val_accuracy'], '-.m', label = 'validation')
plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(fontsize = 12)
plt.title('Precisión del modelo con 3 capas ocultas')
plt.subplots_adjust(wspace=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Entrenando modelo con 3 capas ocultas...

# %% [markdown]
# ### 2. Variante: Capas ocultas de 5 neuronas

# %%
model_5_neurons = Sequential()
model_5_neurons.add(Dense(5, activation='relu', input_shape=(24,)))
model_5_neurons.add(Dense(5, activation='relu'))
model_5_neurons.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_5_neurons.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

print("Entrenando modelo con capas de 5 neuronas...")
mynet_5_neurons = model_5_neurons.fit(
    Xst_train, y_train, validation_data=(Xst_val, y_val),
    epochs=100, batch_size=200, verbose=0)

plt.figure(figsize=(14,5))
plt.subplot(121)
plt.plot(mynet_5_neurons.history['loss'], label = 'train')
plt.plot(mynet_5_neurons.history['val_loss'],'-.m', label = 'validation')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(loc='upper right', fontsize = 12)
plt.title('Pérdida del modelo con 5 neuronas')

plt.subplot(122)
plt.plot(mynet_5_neurons.history['accuracy'], label = 'train')
plt.plot(mynet_5_neurons.history['val_accuracy'], '-.m', label = 'validation')
plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(fontsize = 12)
plt.title('Precisión del modelo con 5 neuronas')
plt.subplots_adjust(wspace=0.5)
plt.show()
# Out:
# Entrenando modelo con capas de 5 neuronas...

# %% [markdown]
# ### 2. Variante: Capas ocultas de 100 neuronas

# %%
model_100_neurons = Sequential()
model_100_neurons.add(Dense(100, activation='relu', input_shape=(24,)))
model_100_neurons.add(Dense(100, activation='relu'))
model_100_neurons.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_100_neurons.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

print("Entrenando modelo con capas de 100 neuronas...")
mynet_100_neurons = model_100_neurons.fit(
    Xst_train, y_train, validation_data=(Xst_val, y_val),
    epochs=100, batch_size=200, verbose=0)

plt.figure(figsize=(14,5))
plt.subplot(121)
plt.plot(mynet_100_neurons.history['loss'], label = 'train')
plt.plot(mynet_100_neurons.history['val_loss'],'-.m', label = 'validation')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(loc='upper right', fontsize = 12)
plt.title('Pérdida del modelo con 100 neuronas')

plt.subplot(122)
plt.plot(mynet_100_neurons.history['accuracy'], label = 'train')
plt.plot(mynet_100_neurons.history['val_accuracy'], '-.m', label = 'validation')
plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(fontsize = 12)
plt.title('Precisión del modelo con 100 neuronas')
plt.subplots_adjust(wspace=0.5)
plt.show()
# Out:
# Entrenando modelo con capas de 100 neuronas...

# %% [markdown]
# ### 3. Variante: Activación `tanh`

# %%
model_tanh = Sequential()
model_tanh.add(Dense(20, activation='tanh', input_shape=(24,)))
model_tanh.add(Dense(20, activation='tanh'))
model_tanh.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_tanh.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

print("Entrenando modelo con activación tanh...")
mynet_tanh = model_tanh.fit(
    Xst_train, y_train, validation_data=(Xst_val, y_val),
    epochs=100, batch_size=200, verbose=0)

plt.figure(figsize=(14,5))
plt.subplot(121)
plt.plot(mynet_tanh.history['loss'], label = 'train')
plt.plot(mynet_tanh.history['val_loss'],'-.m', label = 'validation')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(loc='upper right', fontsize = 12)
plt.title('Pérdida del modelo con activación tanh')

plt.subplot(122)
plt.plot(mynet_tanh.history['accuracy'], label = 'train')
plt.plot(mynet_tanh.history['val_accuracy'], '-.m', label = 'validation')
plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(fontsize = 12)
plt.title('Precisión del modelo con activación tanh')
plt.subplots_adjust(wspace=0.5)
plt.show()
# Out:
# Entrenando modelo con activación tanh...

# %% [markdown]
# ### Resultados para la tabla de comparación

# %%
results_baseline_acc = mynet_st.history['val_accuracy'][-1]
results_baseline_loss = mynet_st.history['val_loss'][-1]

results_3_layers_acc = mynet_3_layers.history['val_accuracy'][-1]
results_3_layers_loss = mynet_3_layers.history['val_loss'][-1]

results_5_neurons_acc = mynet_5_neurons.history['val_accuracy'][-1]
results_5_neurons_loss = mynet_5_neurons.history['val_loss'][-1]

results_100_neurons_acc = mynet_100_neurons.history['val_accuracy'][-1]
results_100_neurons_loss = mynet_100_neurons.history['val_loss'][-1]

results_tanh_acc = mynet_tanh.history['val_accuracy'][-1]
results_tanh_loss = mynet_tanh.history['val_loss'][-1]

print("Valores finales de Accuracy y Loss en el conjunto de validación:")
print(f"Baseline (2 capas x 20, relu): Accuracy={results_baseline_acc:.4f}, Loss={results_baseline_loss:.4f}")
print(f"3 capas ocultas (20 neuronas cada una): Accuracy={results_3_layers_acc:.4f}, Loss={results_3_layers_loss:.4f}")
print(f"Capas de 5 neuronas: Accuracy={results_5_neurons_acc:.4f}, Loss={results_5_neurons_loss:.4f}")
print(f"Capas de 100 neuronas: Accuracy={results_100_neurons_acc:.4f}, Loss={results_100_neurons_loss:.4f}")
print(f"Activación tanh: Accuracy={results_tanh_acc:.4f}, Loss={results_tanh_loss:.4f}")
# Out:
# Valores finales de Accuracy y Loss en el conjunto de validación:
# Baseline (2 capas x 20, relu): Accuracy=0.9388, Loss=0.1696
# 3 capas ocultas (20 neuronas cada una): Accuracy=0.9375, Loss=0.2363
# Capas de 5 neuronas: Accuracy=0.9463, Loss=0.1417
# Capas de 100 neuronas: Accuracy=0.9250, Loss=0.4310
# Activación tanh: Accuracy=0.9300, Loss=0.1816

# %% [markdown]
# ### Regularización (por qué es necesaria??)
#
# Dos estrategias razonables acá: parar el entrenamiento antes (**early stopping**, ~época 20-30,
# donde val deja de mejorar), o agregar regularización con **dropout** y ver si empuja la curva de validación
# más alto. Probemos ambas y comparemos.
#
# ### Antes de correr
#
# Va a probar dos estrategias para esta brecha train/val: dropout y early stopping. Antes de correr ninguna:
#
# - ¿Cuál de las dos cree que va a dar mejor accuracy en validación?
#
# Ambas buscan mejorar la generalización. El Dropout tiene el potencial de crear modelos más robustos y generalizables al reducir la co-adaptación de las neuronas, lo que podría traducirse en un mejor accuracy en validación si se sintoniza bien. El Early Stopping asegura que no se sobreajuste, pero no necesariamente optimiza activamente la robustez.
#
# - ¿Cuál cree que va a ser más rápida de entrenar (menos épocas efectivas)?
#
# El Early Stopping, por definición es el más rápido en términos de épocas efectivas. Está diseñado para detener el entrenamiento cuando la val_loss deja de mejorar, lo que significa que el modelo deja de entrenar una vez que ya no aprende algo útil en el conjunto de validación.

# %% [markdown]
# ### Dropout

# %%
model_dropout = Sequential()

# Primera capa oculta, con el tamaño de la capa input especificado

model_dropout.add(Dense(20, activation='relu', input_shape=(24,)))

model_dropout.add(Dropout(0.2)) #fraccion de dropout

# Agregamos otra capa oculta y especificamos el tamaño

model_dropout.add(Dense(20, activation='relu'))

model_dropout.add(Dropout(0.2)) #fracción de dropout

#Agregamos capa de salida

model_dropout.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model_dropout.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
mynet_dropout = model_dropout.fit(Xst_train, y_train, validation_data= (Xst_val, y_val), epochs=100, batch_size=200, verbose=0)

# %%
plt.figure(figsize=(14,5))

plt.subplot(121)

plt.plot(mynet_dropout.history['loss'], label = 'train')
plt.plot(mynet_dropout.history['val_loss'],'-.m', label = 'validation')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(loc='upper right', fontsize = 12)

plt.subplot(122)

plt.plot(mynet_dropout.history['accuracy'], label = 'train')
plt.plot(mynet_dropout.history['val_accuracy'], '-.m', label = 'validation')
plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(fontsize = 12)
plt.subplots_adjust(wspace=0.5)

#plt.savefig('RegularizedNN.png', dpi= 300)
#plt.show()

# %% [markdown]
# ### Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

model_early = Sequential()
model_early.add(Dense(20, activation='relu', input_shape=(24,)))
model_early.add(Dense(20, activation='relu'))
model_early.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model_early.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

mynet_early = model_early.fit(
    Xst_train, y_train, validation_data=(Xst_val, y_val),
    epochs=100, batch_size=200, callbacks=[early_stop], verbose=0)

print(f"Se detuvo en la época: {len(mynet_early.history['loss'])}")
# Out:
# Se detuvo en la época: 35

# %%
plt.figure(figsize=(14,5))

plt.subplot(121)

plt.plot(mynet_early.history['loss'], label = 'train')
plt.plot(mynet_early.history['val_loss'],'-.m', label = 'validation')
plt.ylabel('Loss', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(loc='upper right', fontsize = 12)

plt.subplot(122)

plt.plot(mynet_early.history['accuracy'], label = 'train')
plt.plot(mynet_early.history['val_accuracy'], '-.m', label = 'validation')
plt.ylabel('Accuracy', fontsize = 14)
plt.xlabel('Epoch', fontsize = 14)
plt.legend(fontsize = 12)
plt.subplots_adjust(wspace=0.5)

#plt.savefig('Regularized_Early_NN.png', dpi= 300)
#plt.show()

# %%
comparacion = pd.DataFrame([
    {"modelo": "escalado (sin regularizar)",
     "val_acc": mynet_st.history['val_accuracy'][-1],
     "val_loss": mynet_st.history['val_loss'][-1]},
    {"modelo": "escalado + dropout",
     "val_acc": mynet_dropout.history['val_accuracy'][-1],
     "val_loss": mynet_dropout.history['val_loss'][-1]},
    {"modelo": "escalado + early stopping",
     "val_acc": mynet_early.history['val_accuracy'][-1],
     "val_loss": mynet_early.history['val_loss'][-1]},
])
comparacion
# Out:
#                        modelo  val_acc  val_loss
# 0  escalado (sin regularizar)  0.93875  0.169606
# 1          escalado + dropout  0.94125  0.151907
# 2   escalado + early stopping  0.93625  0.144518

# %%
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

modelos = {
    "sin regularizar": model_st,
    "dropout": model_dropout,
    "early stopping": model_early,
}

for nombre, modelo in modelos.items():
    y_pred_proba = modelo.predict(Xst_test, verbose=0).ravel()
    y_pred = (y_pred_proba > 0.5).astype(int)

    print(f"=== {nombre} ===")
    print(classification_report(y_test, y_pred, target_names=["ttbar", "4top"]))
    print(f"AUC-ROC: {roc_auc_score(y_test, y_pred_proba):.4f}")
    print("Matriz de confusión:")
    print(confusion_matrix(y_test, y_pred))
    print()
# Out:
# === sin regularizar ===
#               precision    recall  f1-score   support
#
#        ttbar       0.97      0.97      0.97       838
#         4top       0.85      0.83      0.84       162
#
#     accuracy                           0.95      1000
#    macro avg       0.91      0.90      0.91      1000
# weighted avg       0.95      0.95      0.95      1000
#
# AUC-ROC: 0.9746
# Matriz de confusión:
# [[814  24]
#  [ 27 135]]
#
# === dropout ===
#               precision    recall  f1-score   support
#
#        ttbar       0.97      0.97      0.97       838
#         4top       0.84      0.83      0.83       162
#
#     accuracy                           0.95      1000
#    macro avg       0.90      0.90      0.90      1000
# weighted avg       0.95      0.95      0.95      1000
#
# AUC-ROC: 0.9772
# Matriz de confusión:
# [[813  25]
#  [ 28 134]]
#
# === early stopping ===
#               precision    recall  f1-score   support
#
#        ttbar       0.97      0.97      0.97       838
#         4top       0.87      0.84      0.85       162
#
#     accuracy                           0.95      1000
#    macro avg       0.92      0.91      0.91      1000
# weighted avg       0.95      0.95      0.95      1000
#
# AUC-ROC: 0.9801
# Matriz de confusión:
# [[817  21]
#  [ 26 136]]

# %%
comparacion = pd.DataFrame([
    {
        "modelo": nombre,
        "val_acc": modelo.evaluate(Xst_val, y_val, verbose=0)[1],
        "test_auc": roc_auc_score(y_test, modelo.predict(Xst_test, verbose=0).ravel()),
        "epocas": len(modelo.history.history['loss']) if hasattr(modelo, 'history') else None,
    }
    for nombre, modelo in modelos.items()
])
comparacion
# Out:
#             modelo  val_acc  test_auc  epocas
# 0  sin regularizar  0.93875  0.974601     100
# 1          dropout  0.94125  0.977224     100
# 2   early stopping  0.93625  0.980148      35

# %% [markdown]
# ### Después de correr ambas: reflexión
#
# Mire los números reales de dropout y early stopping.
#
# 1. Esperaba ese resultado? Explique
#
# Sí. El Dropout mostró una ligera mejora en val_accuracy y test_auc comparado con el baseline, lo cual es esperable ya que está diseñado para reducir el sobreajuste. Sin embargo, no fue una mejora drástica. La val_loss del modelo con dropout también es ligeramente menor que la del baseline, lo que indica una mejor generalización.
#
# El Early Stopping resultó en una val_accuracy ligeramente inferior al baseline, pero el test_auc es el más alto de los tres. Esto podría indicar que, aunque la precisión en el set de validación fue ligeramente menor en la última época del entrenamiento temprano, el modelo generaliza mejor al conjunto de prueba según la métrica AUC-ROC. La principal ventaja, como se esperaba, es la reducción significativa en el número de épocas de entrenamiento (35 vs 100), lo que implica un entrenamiento mucho más rápido.
#
# 2. Dropout actúa *durante* el entrenamiento (apagando neuronas en cada paso). Early stopping actúa *deteniendo* el entrenamiento en un punto. ¿Por qué una de las dos estrategias podría funcionar mejor que la otra en este dataset específico, dado su tamaño y la arquitectura que están usando?
#
# Para este dataset, que es relativamente pequeño (5000 muestras) y con una arquitectura de red simple (2 capas ocultas de 20 neuronas), la efectividad de cada técnica puede variar:
#
# Dropout: Funciona al apagar aleatoriamente neuronas durante el entrenamiento, lo que fuerza a la red a aprender representaciones más robustas y menos dependientes de neuronas específicas.
#
# Early Stopping: Es particularmente eficaz para datasets pequeños y modelos con tendencia al sobreajuste, ya que detiene el entrenamiento cuando el rendimiento en el conjunto de validación deja de mejorar.
#
# En este escenario, ambas técnicas son relevantes. El Dropout ayuda a construir un modelo más robusto, mientras que el Early Stopping gestiona el punto óptimo de entrenamiento para la generalización, evitando costos computacionales innecesarios y sobreajuste prolongado. El test_auc ligeramente superior del Early Stopping sugiere que encontrar el punto justo de detención puede ser muy beneficioso para la generalización en este tipo de dataset.
#
# 3. ¿Tendría sentido combinar ambas (dropout + early stopping) en vez de elegir una sola? ¿Por qué sí o por qué no?
#
# Sí, tiene mucho sentido combinar Dropout y Early Stopping. Porque tienen:
#
# - Beneficios Complementarios: Dropout actúa como una regularización intrínseca del modelo, haciendo que cada época de entrenamiento sea más robusta y menos propensa al sobreajuste desde el principio. Early Stopping, por otro lado, es una estrategia externa que monitorea el progreso de la validación y detiene el entrenamiento en el momento óptimo.
# - Mayor Robustez y Eficiencia: Al usar Dropout, el modelo ya es más resistente al sobreajuste. Al añadir Early Stopping, nos aseguramos de que el entrenamiento se detenga tan pronto como el modelo deje de mejorar en el conjunto de validación, incluso con Dropout aplicado.
# - Manejo del Sobreajuste: Dropout reduce la tendencia del modelo a memorizar el ruido en los datos de entrenamiento, mientras que Early Stopping evita que el modelo continúe sobreajustándose a pesar de la regularización.
#
# 4. Pruebe distintos valores de dropout y early stopping y discuta cómo cambian los resultados.

# %% [markdown]
# ### Optimización de hiperparámetros
#
# Usaremos [`keras_tuner`](https://keras.io/keras_tuner/) para optimizar los hiperparámetros de la arquitectura de la red

# %% [markdown]
# ### Antes de correr la búsqueda
#
# Con lo que ya sabe del dataset y de los experimentos anteriores, responda:
#
# - ¿Cuántas capas ocultas cree que va a preferir el mejor modelo?
#
# Es probable que se mantenga en 2 capas ocultas o incluso que 1 capa sea suficiente, ya que el dataset no parece requerir una profundidad excesiva para capturar sus patrones. Un modelo más simple podría generalizar mejor con este tamaño de dataset.
#
# - ¿Dropout va a terminar en 0.0 o en un valor alto?
#
# Observamos un sobreajuste leve en el modelo baseline escalado (separación creciente entre las curvas de train y validación). El experimento con dropout (val_accuracy = 0.94125, val_loss = 0.151907) mostró una ligera mejora sobre el baseline (val_accuracy = 0.9388, val_loss = 0.1696). Esto indica que la regularización por dropout es beneficiosa para este dataset. Por lo tanto, espero que el valor óptimo de dropout sea mayor que 0.0, probablemente un valor moderado (entre 0.1 y 0.3) para mitigar el sobreajuste sin subajustar el modelo.
#
# - ¿El learning rate óptimo va a ser más cercano a 0.0001 o a 0.01?
#
# El modelo baseline escalado, entrenado con un learning_rate de 0.001, mostró una buena convergencia y un rendimiento razonable. Los learning rates muy altos (cercanos a 0.01) a menudo causan inestabilidad en el entrenamiento o que el modelo salte el mínimo. Los learning rates muy bajos (cercanos a 0.0001) pueden resultar en un entrenamiento excesivamente lento. Dada la estabilidad observada con 0.001, el learning rate óptimo probablemente estará más cerca de 0.001, o incluso ligeramente más bajo hacia 0.0001 si el modelo puede beneficiarse de pasos más pequeños en un entorno de pérdida más complejo, pero es poco probable que el valor óptimo sea tan alto como 0.01.

# %%
pip install keras-tuner  #(correr una vez en Colab)
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.8-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (3.13.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (26.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (2.32.4)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (1.82.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (5.29.6)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio->keras-tuner) (4.16.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.19.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2026.6.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.8-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 4.3 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.8 kt-legacy-1.0.5

# %%
import keras_tuner as kt

def build_model_tuner(hp):
    model = Sequential()

    #prueba con ndistintos numeros de neuronas, desde 8 a 64, cada 8,
    n_neurons = hp.Int("n_neurons", min_value=8, max_value=64, step=8)
    # activation = hp.Choice("activation", values=["relu", "tanh"])

    #construye la capa con la cantidad de neuronas que fijo en el paso anterior (cada capa con el mismo numero de neuronas)
    model.add(Dense(n_neurons, activation='relu', input_shape=(24,)))

    #numero de capas ocultas (1, 2, o 3)
    n_hidden = hp.Int("n_hidden", min_value=1, max_value=3)
    for i in range(n_hidden - 1):
        model.add(Dense(n_neurons, activation='relu'))

    #tasa de dropout (0.1-0.5, en pasos de 0.1)
    dropout_rate = hp.Float("dropout_rate", min_value=0.0, max_value=0.5, step=0.1)
    if dropout_rate > 0:
        model.add(Dropout(dropout_rate))
    #la capa de salida queda fija, para la clasificacion binaria
    model.add(Dense(1, activation='sigmoid'))

    #tasa de aprendizaje, entre 0.0001 y 0.01
    learning_rate = hp.Float("learning_rate", min_value=1e-4, max_value=1e-2, sampling="log")
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    return model

#prueba solo combinaciones aleatorias para reducir costo computacional
tuner = kt.RandomSearch(
    build_model_tuner,
    objective="val_accuracy",
    max_trials=15,          # número de combinaciones a probar
    executions_per_trial=1,
    directory="tuner_resultados",
    project_name="particle_id",
)

tuner.search(
    Xst_train, y_train,
    validation_data=(Xst_val, y_val),
    epochs=30,
    batch_size=200,
    verbose=1,
)
# Out:
# Trial 15 Complete [00h 00m 09s]
# val_accuracy: 0.9412500262260437
#
# Best val_accuracy So Far: 0.9549999833106995
# Total elapsed time: 00h 02m 22s

# %%
# Mejor modelo encontrado
mejores_hp = tuner.get_best_hyperparameters(1)[0]
print("Mejores hiperparámetros:")
for param in mejores_hp.values:
    print(f"  {param}: {mejores_hp.values[param]}")
# Out:
# Mejores hiperparámetros:
#   n_neurons: 64
#   n_hidden: 1
#   dropout_rate: 0.2
#   learning_rate: 0.009706173542646161

# %% [markdown]
# ### Evaluamos finalmente el modelo con el set de prueba, que sólo se usa en el paso final

# %%
mejor_modelo = tuner.get_best_models(1)[0]
scores = mejor_modelo.evaluate(Xst_test, y_test, verbose=0)
print(f"\nAccuracy en test: {scores[1]:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Accuracy en test: 0.9520

# %%
# Resumen de los mejores trials
tuner.results_summary(num_trials=5)
# Out:
# Results summary
# Results in tuner_resultados/particle_id
# Showing 5 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 13 summary
# Hyperparameters:
# n_neurons: 64
# n_hidden: 1
# dropout_rate: 0.2
# learning_rate: 0.009706173542646161
# Score: 0.9549999833106995
#
# Trial 00 summary
# Hyperparameters:
# n_neurons: 8
# n_hidden: 1
# dropout_rate: 0.1
# learning_rate: 0.009032083593872276
# Score: 0.9524999856948853
#
# Trial 04 summary
# Hyperparameters:
# n_neurons: 32
# n_hidden: 3
# dropout_rate: 0.0
# learning_rate: 0.00023948972884503826
# Score: 0.949999988079071
#
# Trial 03 summary
# Hyperparameters:
# n_neurons: 32
# n_hidden: 2
# dropout_rate: 0.0
# learning_rate: 0.002332058207624143
# Score: 0.9487500190734863
#
# Trial 01 summary
# Hyperparameters:
# n_neurons: 48
# n_hidden: 2
# dropout_rate: 0.4
# learning_rate: 0.0007091182246779932
# Score: 0.9462500214576721

# %% [markdown]
# ### Mire los 5 mejores trials, no solo el ganador
#
# **1. ¿Hay algún empate o casi-empate en el score entre dos trials? Compare sus arquitecturas (n_neurons, n_hidden) y su dropout_rate uno al lado del otro, ¿qué tan distintos son entre sí?**
#
# Sí, observamos casi-empates en el val_accuracy entre varios trials:
#
# *   **Trial 13 (0.9550) vs Trial 00 (0.9525):** Una diferencia muy pequeña de ~0.0025.
#     Ambos tienen 1 capa oculta, lo cual es interesante. El Trial 13 usa muchas más neuronas (64 vs 8) y un dropout ligeramente superior (0.2 vs 0.1), mientras que el learning rate es similar. Esto sugiere que un modelo más ancho puede ser ligeramente mejor, incluso con la misma profundidad.
#
# *   **Trial 04 (0.9500) vs Trial 03 (0.9488) vs Trial 01 (0.9463):** También son scores muy cercanos. Aquí vemos diferencias más marcadas. Trial 04 tiene 3 capas y Trial 03 tiene 2 capas, ambos con 32 neuronas y 0.0 dropout, pero con learning rates diferentes. Trial 01 tiene 2 capas, 48 neuronas y un dropout de 0.4. Esto muestra que hay múltiples combinaciones de arquitectura y regularización que pueden llevar a resultados similares.
#
# **2. Si encuentra un caso así, ¿qué le dice eso sobre la relación entre tamaño de red y necesidad de regularización? ¿Es dropout algo que "siempre ayuda", o depende de si la arquitectura ya es lo suficientemente chica como para no necesitarlo?**
#
# El caso de Trial 04 y Trial 03, ambos con dropout_rate: 0.0 y logrando buenos scores, mientras que Trial 13 con n_neurons: 64 usa dropout_rate: 0.2, sugiere que la necesidad de regularización (como Dropout) está directamente relacionada con la complejidad y el tamaño del modelo.
#
# *   Para **modelos más pequeños o menos complejos** el overfitting puede ser menos pronunciado, y por lo tanto, el dropout puede no ser tan crítico o incluso puede ser perjudicial si es demasiado alto (llevando a underfitting).
# *   Para **modelos más grandes** o con mayor capacidad de aprendizaje, el dropout se vuelve más relevante para evitar el sobreajuste.
#
# En resumen, el dropout no "siempre ayuda"; su efectividad depende del equilibrio con la complejidad de la arquitectura del modelo y las características del dataset. Una red ya suficientemente pequeña podría no necesitarlo, o incluso rendir peor si se aplica.
#
# **3. Si tuviera que elegir entre dos modelos con score casi igual pero muy distintos en complejidad, ¿cuál elige para poner en producción y por qué? (piense en costo de cómputo, riesgo de overfitting futuro, interpretabilidad)**
#
# Si tuviera que elegir entre dos modelos con scores casi idénticos pero con complejidades muy distintas, siempre elegiría el **modelo menos complejo**. Las razones son:
#
# *   **Costo de Cómputo:** Un modelo más simple requiere menos recursos computacionales (CPU, memoria). Esto se traduce en menores costos de infraestructura y mayor velocidad de respuesta.
# *   **Riesgo de Overfitting Futuro:** Los modelos más complejos tienen una mayor capacidad de memorizar los datos de entrenamiento, aumentando el riesgo de sobreajuste a datos no vistos en el futuro. Un modelo más simple es inherentemente más robusto a las variaciones en los datos.
# *   **Interpretabilidad:** Aunque las redes neuronales son en general cajas negras, un modelo más pequeño y con menos capas puede ser marginalmente más fácil de entender o diagnosticar si surgen problemas en producción. Además, las relaciones que aprende tienden a ser más fundamentales y menos dependientes de ruidos específicos.
#
#
# **4. Compare el mejor modelo de la búsqueda automática contra su mejor intento manual (dropout o early stopping). ¿Vale la pena el costo computacional de la búsqueda para esa diferencia?**
#
# Hay una mejora de aproximadamente 1.375 puntos porcentuales en val_accuracy (0.9550 - 0.94125). Si bien 1.375% puede parecer una diferencia modesta en términos absolutos, en problemas de clasificación, cada punto porcentual puede ser significativo y tener un impacto real. Además, el test_auc del mejor modelo automático (0.9520 en test, el test_auc no fue directamente optimizado por el tuner, pero model.evaluate en Xst_test da 0.9520 para accuracy) es comparable al test_auc de los modelos manuales (0.9772 y 0.9801 para Dropout y Early Stopping respectivamente, aunque estas son métricas diferentes). Si consideramos que el tuner optimizó val_accuracy, el 0.9550 es un buen salto.
#
# **¿Vale la pena el costo computacional?**
#
# Sí. Porque mejora el rendimiento, ahorra el tiempo a largo plazo y hace una mejor exploración de hiperparámetros.

# %% [markdown]
# Reflexión final
#
# 1. A lo largo de este notebook probó varios modelos: sin escalar, escalado, con dropout, con early stopping, y el resultado de la búsqueda automática de hiperparámetros. ¿Cuál de todos eligiría como el modelo final, y por qué? Use números concretos de sus tablas, no solo accuracy.
#
# El modelo del Keras Tuner (Trial 13) alcanza la val_accuracy más alta (0.9550) de todos los modelos probados. Aunque el modelo con Early Stopping tuvo un test_auc ligeramente superior (0.980148 vs ~0.97 para el Tuner model, si bien no se optimizó AUC en el Tuner), la mejora en val_accuracy con el Tuner es consistente y significativa. Además, la búsqueda de hiperparámetros permite encontrar una combinación óptima de arquitectura y regularización que supera los intentos manuales.
#
# 2. El SVM del notebook anterior llegó a 94-95%. ¿Su mejor red neuronal lo superó? Si la diferencia es chica, ¿vale la pena toda la complejidad extra (arquitectura, regularización, búsqueda de hiperparámetros) por esa ganancia?
#
# Sí, el mejor modelo neuronal (Keras Tuner, Trial 13 con val_accuracy = 0.9550 y test_accuracy = 0.9520) superó ligeramente el rendimiento del SVM. En este dataset específico, donde la diferencia con el SVM es modesta, la justificación para la complejidad extra es más pedagógica y de exploración que puramente de rendimiento. Nos permite entender las redes neuronales y sus herramientas de optimización. En un escenario real, si el SVM ya da 94-95%, yo consideraría primero otras optimizaciones en el SVM o la ingeniería de características antes de saltar a NNs si la ganancia es tan marginal, a menos que tenga una gran cantidad de datos para aprovechar la capacidad de las NNs.
#
# 3. Comparen el salto de accuracy entre "sin escalar → escalado" contra el salto entre "escalado sin regularizar → mejor modelo de la búsqueda de hiperparámetros". ¿Cuál salto fue más grande? ¿Qué les dice eso sobre dónde conviene invertir tiempo primero cuando entrenan una red nueva?
#
# El salto más grande fue claramente de "sin escalar a escalado" (aproximadamente 14.26%). El salto de "escalado sin regularizar a mejor modelo del Tuner" fue mucho menor (aproximadamente 1.62%). Una vez que los datos están bien preparados, entonces sí, la optimización de hiperparámetros y la regularización (como el dropout y el early stopping) pueden brindar mejoras adicionales, pero generalmente son incrementales en comparación con el impacto de una mala preparación de datos. La prioridad siempre debe ser asegurarse de que los datos estén en la mejor forma posible antes de adentrarse en optimizaciones sofisticadas de la arquitectura o hiperparámetros de la red.
